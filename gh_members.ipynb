# %%
### Import Libraries

# %%
import pandas as pd
import seaborn as sn
from nltk.corpus import names
from nltk import NaiveBayesClassifier as NBC
from nltk import classify
import random
#import gender_guesser.detector as gender

# %%
### Obtain Data

# %%
df_gh = pd.read_csv('ghmembers.csv')

# %%
df_gh.head()
# Out:
#   web-scraper-order                              web-scraper-start-url  \
# 0   1658430135-5725  https://www.grasshopper3d.com/profiles/friend/...
# 1   1658438988-8641  https://www.grasshopper3d.com/profiles/friend/...
# 2  1658527974-38286  https://www.grasshopper3d.com/profiles/friend/...
# 3  1658493696-26853  https://www.grasshopper3d.com/profiles/friend/...
# 4  1658479879-22206  https://www.grasshopper3d.com/profiles/friend/...
#
#            element                                       element-href  \
# 0            ami11  https://www.grasshopper3d.com/profile/ami11?xg...
# 1         Chris Xu  https://www.grasshopper3d.com/profile/ChrisXu?...
# 2      Francis Cox  https://www.grasshopper3d.com/profile/FrancisC...
# 3  Margorie Durant  https://www.grasshopper3d.com/profile/Margorie...
# 4             John  https://www.grasshopper3d.com/profile/John999?...
#
#               name                                          name-html  \
# ...

# %%
df_gh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41548 entries, 0 to 41547
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   web-scraper-order      41548 non-null  object
#  1   web-scraper-start-url  41548 non-null  object
#  2   element                41547 non-null  object
#  3   element-href           41548 non-null  object
#  4   name                   41547 non-null  object
#  5   name-html              41548 non-null  object
#  6   gender                 41545 non-null  object
#  7   location-2             41526 non-null  object
#  8   location-3             869 non-null    object
#  9   blog-post-number       41306 non-null  object
#  10  groups-number          41306 non-null  object
#  11  photo-albums-number    41306 non-null  object
#  12  company                23094 non-null  object
#  13  website                3962 non-null   object
# dtypes: object(14)
# ...

# %%
#Check for missing data
df_gh.isna().sum()
# Out:
# web-scraper-order            0
# web-scraper-start-url        0
# element                      1
# element-href                 0
# name                         1
# name-html                    0
# gender                       3
# location-2                  22
# location-3               40679
# blog-post-number           242
# groups-number              242
# photo-albums-number        242
# company                  18454
# website                  37586
# dtype: int64

# %%
df_gh.drop(columns=['element-href', 'name-html', 'location-3', 'web-scraper-order', 'web-scraper-start-url', 'company', 'website'])
# Out:
#                element             name            gender  \
# 0                ami11            ami11          istanbul
# 1             Chris Xu         Chris Xu  Philadelphia, PA
# 2          Francis Cox      Francis Cox    Washington, DC
# 3      Margorie Durant  Margorie Durant      Bethesda, MD
# 4                 John             John     Port Stephens
# ...                ...              ...               ...
# 41543      bikitha lee      bikitha lee             dubai
# 41544         Yew Chao         Yew Chao            Female
# 41545             Jung             Jung          Den Haag
# 41546        Lum Cheng        Lum Cheng        QUARRY BAY
# 41547    Paul Veternik    Paul Veternik           München
#
#                  location-2 blog-post-number groups-number photo-albums-number
# 0                    Turkey       Blog Posts        Groups        Photo Albums
# 1             United States       Blog Posts        Groups        Photo Albums
# ...

# %%
#Expand Address
#df_location = df_gh['user - location'].str.split(',', expand=True)

# %%
#df_location

# %%
#df = df_gh.join(df_location)

# %%
df_gh.isna().sum()
# Out:
# web-scraper-order            0
# web-scraper-start-url        0
# element                      1
# element-href                 0
# name                         1
# name-html                    0
# gender                       3
# location-2                  22
# location-3               40679
# blog-post-number           242
# groups-number              242
# photo-albums-number        242
# company                  18454
# website                  37586
# dtype: int64

# %%
#Expand Name
df_names = df_gh['name'].str.split(' ', expand=True)

# %%
df_names.head()
# Out:
#           0       1     2     3     4     5     6     7
# 0     ami11    None  None  None  None  None  None  None
# 1     Chris      Xu  None  None  None  None  None  None
# 2   Francis     Cox  None  None  None  None  None  None
# 3  Margorie  Durant  None  None  None  None  None  None
# 4      John    None  None  None  None  None  None  None

# %%
df_names.drop(columns = 1)
# Out:
#               0     2     3     4     5     6     7
# 0         ami11  None  None  None  None  None  None
# 1         Chris  None  None  None  None  None  None
# 2       Francis  None  None  None  None  None  None
# 3      Margorie  None  None  None  None  None  None
# 4          John  None  None  None  None  None  None
# ...         ...   ...   ...   ...   ...   ...   ...
# 41543   bikitha  None  None  None  None  None  None
# 41544       Yew  None  None  None  None  None  None
# 41545      Jung  None  None  None  None  None  None
# 41546       Lum  None  None  None  None  None  None
# 41547      Paul  None  None  None  None  None  None
#
# [41548 rows x 7 columns]

# %%
def gender_features(word):
    return {'last_letter':word[-1]}

# %%
maleNames = [ (name, ‘male’) for name in names.words(‘male.txt’) ]
femaleNames = [ (name, ‘female’) for name in names.words(‘female.txt’) ]
# Out:
#   File "<ipython-input-36-29da53323ca8>", line 1
#     maleNames = [ (name, ‘male’) for name in names.words(‘male.txt’) ]
#                               ^
# SyntaxError: invalid character in identifier
